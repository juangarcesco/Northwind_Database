# %% [markdown]
# <a href="https://colab.research.google.com/github/juangarcesco/Northwind_Database/blob/main/Northwind_Database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importacion de librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rnd
import seaborn as sns
from scipy.stats import zscore

# %% [markdown]
# ## Carga de datos csv

# %%
customers = pd.read_csv('Northwind_Customers.csv', low_memory=False)
categories = pd.read_csv('Northwind_Categories.csv', low_memory=False)
employees = pd.read_csv('Northwind_Employees.csv', low_memory=False)
orders = pd.read_csv('Northwind_Orders.csv', low_memory=False)
products = pd.read_csv('Northwind_Products.csv', low_memory=False)
suppliers = pd.read_csv('Northwind_Suppliers.csv', low_memory=False)
orders_details = pd.read_csv('Northwind_ OrderDetails.csv', low_memory=False)
shippers = pd.read_csv('Northwind_ Shippers.csv', low_memory=False)

# %% [markdown]
# ## Visualizacion de la tabla

# %%
customers
# Out:
#     CustomerID                        CustomerName         ContactName  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taquería      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                  Berglunds snabbköp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#                           Address         City PostalCode  Country  \
# ...

# %%
categories
# Out:
#    CategoryID    CategoryName  \
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           5  Grains/Cereals
# 5           6    Meat/Poultry
# 6           7         Produce
# 7           8         Seafood
#
#                                          Description
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 3                                            Cheeses
# 4                Breads, crackers, pasta, and cereal
# 5                                     Prepared meats
# 6                          Dried fruit and bean curd
# 7                                   Seaweed and fish

# %%
employees
# Out:
#    EmployeeID FirstName   LastName   BirthDate       Photo  \
# 0           1     Nancy    Davolio   8/12/1968  EmpID1.pic
# 1           2    Andrew     Fuller  19/02/1952  EmpID2.pic
# 2           3     Janet  Leverling  30/08/1963  EmpID3.pic
# 3           4  Margaret    Peacock  19/09/1958  EmpID4.pic
# 4           5    Steven   Buchanan   3/04/1955  EmpID5.pic
# 5           6   Michael     Suyama   7/02/1963  EmpID6.pic
# 6           7    Robert       King   1960-5-29  EmpID7.pic
# 7           8     Laura   Callahan   9/01/1958  EmpID8.pic
# 8           9      Anne  Dodsworth   7/02/1969  EmpID9.pic
#
#                                                Notes
# 0  La educación incluye una licenciatura en psico...
# 1  Andrew recibió su comercial de BTS y un doctor...
# 2  Janet tiene una licenciatura en química de Bos...
# 3  Margaret tiene una licenciatura en literatura ...
# 4  Steven Buchanan se graduó de St. Universidad A...
# 5  Michael se graduó de la Universidad de Sussex ...
# ...

# %%
orders
# Out:
#      OrderID  CustomerID  EmployeeID   OrderDate  ShipperID
# 0      10248          90           5  1996-07-04          3
# 1      10249          81           6  1996-07-05          1
# 2      10250          34           4  1996-07-08          2
# 3      10251          84           3  1996-07-08          1
# 4      10252          76           4  1996-07-09          2
# ..       ...         ...         ...         ...        ...
# 825    11073          58           2  1998-05-05          2
# 826    11074          73           7  1998-05-06          2
# 827    11075          68           8  1998-05-06          2
# 828    11076           9           4  1998-05-06          2
# 829    11077          65           1  1998-05-06          2
#
# [830 rows x 5 columns]

# %%
suppliers
# Out:
#     SupplierID                            SupplierName  \
# 0            1                           Exotic Liquid
# 1            2              New Orleans Cajun Delights
# 2            3               Grandma Kelly's Homestead
# 3            4                           Tokyo Traders
# 4            5      Cooperativa de Quesos 'Las Cabras'
# 5            6                                Mayumi's
# 6            7                           Pavlova, Ltd.
# 7            8                Specialty Biscuits, Ltd.
# 8            9                        PB Knäckebröd AB
# 9           10               Refrescos Americanas LTDA
# 10          11             Heli Süßwaren GmbH & Co. KG
# 11          12       Plutzer Lebensmittelgroßmärkte AG
# 12          13  Nord-Ost-Fisch Handelsgesellschaft mbH
# 13          14                 Formaggi Fortini s.r.l.
# 14          15                         Norske Meierier
# 15          16                       Bigfoot Breweries
# ...

# %%
products
# Out:
#     ProductID                      ProductName  SupplierID  CategoryID  \
# 0           1                            Chais           1           1
# 1           2                            Chang           1           1
# 2           3                    Aniseed Syrup           1           2
# 3           4     Chef Anton's Cajun Seasoning           2           2
# 4           5           Chef Anton's Gumbo Mix           2           2
# ..        ...                              ...         ...         ...
# 72         73                       Röd Kaviar          17           8
# 73         74                    Longlife Tofu           4           7
# 74         75             Rhönbräu Klosterbier          12           1
# 75         76                     Lakkalikööri          23           1
# 76         77  Original Frankfurter grüne Soße          12           2
#
#                    Unit  Price
# 0    10 boxes x 20 bags  18.00
# 1    24 - 12 oz bottles  19.00
# ...

# %%
orders_details
# Out:
#       OrderDetailID  OrderID  ProductID  Quantity
# 0                 1    10248         11        12
# 1                 2    10248         42        10
# 2                 3    10248         72         5
# 3                 4    10249         14         9
# 4                 5    10249         51        40
# ...             ...      ...        ...       ...
# 2150           2151    11077         64         2
# 2151           2152    11077         66         1
# 2152           2153    11077         73         2
# 2153           2154    11077         75         4
# 2154           2155    11077         77         2
#
# [2155 rows x 4 columns]

# %%
shippers
# Out:
#    ShipperID       ShipperName           Phone
# 0          1    Speedy Express  (503) 555-9831
# 1          2    United Package  (503) 555-3199
# 2          3  Federal Shipping  (503) 555-9931

# %% [markdown]
# # CUSTOMERS

# %% [markdown]
# ## Tamaño de tabla

# %%
customers.shape
# Out:
# (91, 8)

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    91 non-null     int64
#  1   CustomerName  91 non-null     object
#  2   ContactName   91 non-null     object
#  3   Address       91 non-null     object
#  4   City          91 non-null     object
#  5   PostalCode    90 non-null     object
#  6   Country       91 non-null     object
#  7   Coordinates   91 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 5.8+ KB

# %% [markdown]
# ## Ajuste de datatypes

# %%
df['CustomerID'] = pd.to_numeric(df['CustomerID'], errors='coerce', downcast='integer')
df['City'] = df['City'].astype('category')
df['Country'] = df['Country'].astype('category')

# %%
total_unica_customer_name = df['CustomerName'].nunique()
total_unica_customer_name
# Out:
# 91

# %%
total_unica_Country = df['Country'].nunique()
total_unica_Country
# Out:
# 21

# %%
total_unica_City = df['City'].nunique()
tabla_desglose = conteo_ciudades_por_pais.reset_index()
tabla_desglose
# Out:
#         Country  City
# 0     Argentina     3
# 1       Austria     2
# 2       Belgium     2
# 3        Brazil     9
# 4        Canada     3
# 5       Denmark     2
# 6       Finland     2
# 7        France    11
# 8       Germany    11
# 9       Ireland     1
# 10        Italy     3
# 11       Mexico     5
# 12       Norway     1
# 13       Poland     1
# 14     Portugal     2
# 15        Spain     5
# 16       Sweden     2
# 17  Switzerland     2
# 18           UK     7
# 19          USA    13
# 20    Venezuela     4
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['Country'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# tabla_desglose['City'].plot(kind='hist', bins=20, title='City')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %%
# Agrupar por país y contar el número de ciudades
conteo_ciudades_por_pais = df.groupby('Country')['City'].count()
conteo_ciudades_por_pais
# Out:
# <ipython-input-57-a6e4db2e005d>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   conteo_ciudades_por_pais = df.groupby('Country')['City'].count()
# Country
# Argentina       3
# Austria         2
# Belgium         2
# Brazil          9
# Canada          3
# Denmark         2
# Finland         2
# France         11
# Germany        11
# Ireland         1
# Italy           3
# Mexico          5
# Norway          1
# Poland          1
# Portugal        2
# Spain           5
# Sweden          2
# Switzerland     2
# UK              7
# USA            13
# Venezuela       4
# Name: City, dtype: int64
